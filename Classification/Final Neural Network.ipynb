# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mglearn

df = pd.read_csv("processed_classification.csv")
df = df[['Sex_M', 'Sex_F', 'Age', 'Time', 'Nbr_Warts', 'Type_1',
       'Type_2', 'Type_3', 'Area', 'Induration_diameter', 'Result']]

df
# Out:
#     Sex_M  Sex_F       Age      Time  Nbr_Warts  Type_1  Type_2  Type_3  \
# 0       1      0  0.170732  0.113636   0.764706       0       0       1
# 1       1      0  0.024390  0.863636   0.058824       1       0       0
# 2       1      0  0.292683  0.318182   0.470588       0       0       1
# 3       1      0  0.121951  0.636364   0.294118       1       0       0
# 4       1      0  0.000000  0.363636   0.117647       0       0       1
# ..    ...    ...       ...       ...        ...     ...     ...     ...
# 79      1      0  0.609756  0.409091   0.411765       0       0       1
# 80      1      0  0.560976  0.590909   0.411765       0       1       0
# 81      1      0  0.756098  0.954545   0.176471       1       0       0
# 82      1      0  0.414634  1.000000   0.470588       1       0       0
# 83      0      1  0.195122  0.522727   0.294118       1       0       0
#
#         Area  Induration_diameter  Result
# 0   0.090726             1.000000       1
# ...

# %%
y = df['Result']

X_DataFrame = df[['Sex_M', 'Sex_F', 'Age', 'Time', 'Nbr_Warts', 'Type_1',
       'Type_2', 'Type_3', 'Area', 'Induration_diameter']]

X = X_DataFrame.to_numpy()

# %% [markdown]
# # Split the Dataset intoTrain and Test sets

# %%
from sklearn.model_selection import train_test_split 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10)

print (" train X = ", X_train.shape, " --- train y = ", y_train.shape)

print (" test X = ", X_test.shape, " --- test Y = ", y_test.shape)
# Out:
#  train X =  (67, 10)  --- train y =  (67,)
#  test X =  (17, 10)  --- test Y =  (17,)

# %% [markdown]
# # Testing hyperparameters for the classifier

# %%
from sklearn.neural_network import MLPClassifier
from sklearn import metrics

for i in range(1, 4):
    for j in range(1, 10):
        for k in ['adam', 'sgd', 'lbfgs']:          
            for l in np.linspace(0.0001, 0.05, 10):
                clf = MLPClassifier(solver = k,  alpha = l, hidden_layer_sizes=(i, j), random_state = 1, max_iter = 500)
                clf.fit(X_train, y_train)
                y_pred = clf.predict(X_test)
                if (metrics.accuracy_score(y_pred,y_test) >= 0.89):
                    print('The accuracy of the Multi-layer Perceptron is :{} for {} layers, {} neurons, {} alpha, and {} solver'.format(metrics.accuracy_score(y_pred,y_test), i, j, l, k))
# Out:
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
from sklearn.neural_network import MLPClassifier
from sklearn import metrics

for i in range(1, 4):
    for j in range(1, 10):
        for k in ['adam', 'sgd', 'lbfgs']:
            for m in ['tanh', 'logistic', 'relu']:
                for l in np.linspace(0.0001, 0.05, 10):
                    clf_act = MLPClassifier(solver = k,  alpha = l, activation = m, hidden_layer_sizes=(i, j), random_state = 1, max_iter = 200)
                    clf_act.fit(X_train, y_train)
                    y_pred_act = clf_act.predict(X_test)
                    if (metrics.accuracy_score(y_pred_act,y_test) >= 0.89):
                        print('The accuracy of the Multi-layer Perceptron is :{} for {} layers, {} neurons, {} alpha, {} solver, and {} activation function'.format(metrics.accuracy_score(y_pred,y_test), i, j, l, k, m))

#Further tests will help to widen the set of possible alphas (100 possible alpha values instead of 10) to try to find better and more accurate results 
#We try those alpha values on different solvers but with the same Relu activation function, which gave the best results in this first case
# Out:
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
#lbfgs SOLVER

for i in range(1, 4):
    for j in range(1, 10):
        for l in np.linspace(0.0001, 0.05, 100):
            clf = MLPClassifier(solver = 'lbfgs',  alpha = l, hidden_layer_sizes=(i, j), random_state = 1, max_iter = 200)
            clf.fit(X_train, y_train)
            y_pred = clf.predict(X_test)
            if (metrics.accuracy_score(y_pred,y_test) >= 0.89):
                print('The accuracy of the Multi-layer Perceptron is :{} for {} layers, {} neurons, {} alpha'.format(metrics.accuracy_score(y_pred,y_test), i, j, l))
# Out:
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ...

# %%
#adam SOLVER

for i in range(1, 4):
    for j in range(1, 10):
        for l in np.linspace(0.0001, 0.05, 100):
            clf = MLPClassifier(solver = 'adam',  alpha = l, hidden_layer_sizes=(i, j), random_state = 1, max_iter = 200)
            clf.fit(X_train, y_train)
            y_pred = clf.predict(X_test)
            if (metrics.accuracy_score(y_pred,y_test) >= 0.89):
                print('The accuracy of the Multi-layer Perceptron is :{} for {} layers, {} neurons, {} alpha'.format(metrics.accuracy_score(y_pred,y_test), i, j, l))
# Out:
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
#sgd SOLVER

for i in range(1, 4):
    for j in range(1, 10):
        for l in np.linspace(0.0001, 0.05, 100):
            clf = MLPClassifier(solver = 'sgd',  alpha = l, hidden_layer_sizes=(i, j), random_state = 1, max_iter = 200)
            clf.fit(X_train, y_train)
            y_pred = clf.predict(X_test)
            if (metrics.accuracy_score(y_pred,y_test) >= 0.89):
                print('The accuracy of the Multi-layer Perceptron is :{} for {} layers, {} neurons, {} alpha'.format(metrics.accuracy_score(y_pred,y_test), i, j, l))
# Out:
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
'''
Best parameters for the model are the following :

Number of layers = 2
Number of neurons = 9
Alpha ~= [0.002116161616161616, 0.026814141414141415], we take 0.016733333333333333
Solver = lbfgs
Activation = ReLu (default)

This set of parameters produces an accuracy of 0.9411764705882353

'''
# Out:
# '\nBest parameters for the model are the following :\n\nNumber of layers = 2\nNumber of neurons = 9\nAlpha ~= [0.002116161616161616, 0.026814141414141415], we take 0.016733333333333333\nSolver = lbfgs\nActivation = Relu (default)\n\nThis set of parameters produces an accuracy of 0.9411764705882353\n\n'

# %%
clf = MLPClassifier(solver='lbfgs',  alpha = 0.016733333333333333, hidden_layer_sizes=(2, 9), max_iter=200, random_state = 1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
y_train_pred = clf.predict(X_train)           

print('Train set accuracy: '+'{}'.format(metrics.accuracy_score(y_train, y_train_pred)))                
print('Test set accuracy: '+'{}'.format(metrics.accuracy_score(y_test, y_pred)))
# Out:
# Train set accuracy: 0.7761194029850746
# Test set accuracy: 0.9411764705882353

# %%
#Classification report on the obtained results

from sklearn.metrics import classification_report

print('Results on the test set:')
print(classification_report(y_test, y_pred))
# Out:
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       0.94      1.00      0.97        15
#
#     accuracy                           0.94        17
#    macro avg       0.97      0.75      0.82        17
# weighted avg       0.94      0.94      0.93        17

# %% [markdown]
# # Trying to optimizing hyperparameters using GridSerachCV

# %%
#We try to optimize the classifier hyperparamaters using GridsearchCV algorithm (other than the number and sizes of hidden layers)
#It does the process of performing hyperparameter tuning in order to determine the optimal values for a given model
#we pass predefined values for hyperparameters to the GridSearchCV function by defining a dictionary in which we mention a particular hyperparameter along with the values it can take

parameter_space = {
    'hidden_layer_sizes': (2, 9),
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam', 'lbfgs'],
    'alpha': np.linspace(0.0001, 0.05, 100),
    'learning_rate': ['constant','adaptive'],
}

# %%
#Initializing the GridsearchCV

from sklearn.model_selection import GridSearchCV

mlp_grid = MLPClassifier(max_iter=(200))

clf_grid = GridSearchCV(mlp_grid, parameter_space, n_jobs=-1, cv=5)
clf_grid.fit(X_train, y_train)
# Out:
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# GridSearchCV(cv=5, estimator=MLPClassifier(), n_jobs=-1,
#              param_grid={'activation': ['tanh', 'relu'],
#                          'alpha': array([0.0001    , 0.00060404, 0.00110808, 0.00161212, 0.00211616,
#        0.0026202 , 0.00312424, 0.00362828, 0.00413232, 0.00463636,
#        0.0051404 , 0.00564444, 0.00614848, 0.00665253, 0.00715657,
#        0.00766061, 0.00816465, 0.00866869, 0.00917273, 0.00967677,
#        0.01018081, 0.01068485, 0.01...
#        0.03790303, 0.03840707, 0.03891111, 0.03941515, 0.03991919,
# ...

# %%
#To report different results based on the set of parameters 

means = clf_grid.cv_results_['mean_test_score']
stds = clf_grid.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf_grid.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# 0.747 (+/-0.054) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 2, 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.582 (+/-0.334) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 2, 'learning_rate': 'constant', 'solver': 'adam'}
# 0.820 (+/-0.184) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 2, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.747 (+/-0.054) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 2, 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.747 (+/-0.054) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 2, 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.804 (+/-0.231) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 2, 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.732 (+/-0.063) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 9, 'learning_rate': 'constant', 'solver': 'sgd'}
# ...

# %%
#To get the best parameters

print('Best parameters found:\n', clf_grid.best_params_)
# Out:
# Best parameters found:
#  {'activation': 'tanh', 'alpha': 0.002116161616161616, 'hidden_layer_sizes': 2, 'learning_rate': 'adaptive', 'solver': 'lbfgs'}

# %%
#To test the accuracy of the best parameters

clf_test = MLPClassifier(solver='lbfgs', activation = 'tanh', alpha = 0.002116161616161616, hidden_layer_sizes=(2, 9), learning_rate = 'adaptive', max_iter=200, random_state=1)
clf_test.fit(X_train, y_train)
y_pred_test = clf_test.predict(X_test)

metrics.accuracy_score(y_pred_test,y_test)
# Out:
# C:\Users\windows\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 0.5882352941176471

# %%
from sklearn.metrics import classification_report

y_grid, y_pred_grid = y_test , clf_grid.predict(X_test)

print('Results on the test set:')
print(classification_report(y_grid, y_pred_grid))
# Out:
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.12      0.50      0.20         2
#            1       0.89      0.53      0.67        15
#
#     accuracy                           0.53        17
#    macro avg       0.51      0.52      0.43        17
# weighted avg       0.80      0.53      0.61        17

# %%
metrics.accuracy_score(y_grid, y_pred_grid)
# Out:
# 0.5294117647058824

# %%
'''
We notice that using GridSearchCV to find the best hyperparameters is not the optimal way to do it, doing it with for loops seems to be better
One of the reasons is the size of the dataset, GridsearchCV cannot produce accurate enough results for the size of our dataset
'''

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

confusion_mc = confusion_matrix(y_test, y_pred)

df_cm = pd.DataFrame(confusion_mc, index = [i for i in range(0,2)], columns = [i for i in range(0,2)])

plt.figure(figsize=(5, 5))

sns.heatmap(df_cm, annot=True)

plt.title('Neural Network Accuracy:\n{0:.6f}'.format(accuracy_score(y_test, y_pred)))
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 24.0, 'Predicted label')
